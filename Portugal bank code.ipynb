# %% [markdown]
# #  ‘Portugal Bank Marketing’ dataset

# %% [markdown]
# Bank client data:
#
# 1) age (numeric)
#
# 2) job: type of job (categorical:"admin.","bluecollar","entrepreneur","housemaid","management","retired","self-employed","services","student","technician","unemployed","unknown")
#
# 3) marital: marital status (categorical: "divorced","married","single","unknown"; note: "divorced" means divorced or widowed)
#
# 4) education: education of individual (categorical: "basic.4y","basic.6y","basic.9y","high.school","illiterate","professional.course","university.degree","unknown")
#
# 5) default: has credit in default? (categorical: "no","yes","unknown")
#
# 6) housing: has housing loan? (categorical: "no","yes","unknown")
#
# 7) loan: has personal loan? (categorical: "no","yes","unknown")
#
# Related with the last contact of the current campaign:
#
# 8) contact: contact communication type (categorical: "cellular","telephone")
#
# 9) month: last contact month of year (categorical: "jan", "feb", "mar", …, "nov", "dec")
#
# 10) dayofweek: last contact day of the week (categorical: "mon","tue","wed","thu","fri")
#
# 11) duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y="no"). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# Other attributes:
#
# 12) campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 13) pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#
# 14) previous: number of contacts performed before this campaign and for this client (numeric)
#
# 15) poutcome: outcome of the previous marketing campaign (categorical: "failure","nonexistent","success")
#
# Social and economic context attributes
#
# 16) emp.var.rate: employment variation rate - quarterly indicator (numeric)
#
# 17) cons.price.idx: consumer price index - monthly indicator (numeric)
#
# 18) cons.conf.idx: consumer confidence index - monthly indicator (numeric)
#
# 19) concave points_se: standard error for number of concave portions of the contour
#
# 20) euribor3m: euribor 3 month rate - daily indicator (numeric)
#
# 21) nr.employed: number of employees - quarterly indicator (numeric)
#
# Output variable (desired target):
#
# 22) y: has the client subscribed a term deposit? (binary: "yes","no")

# %% [markdown]
# Bank client data:
#
# 1) age (numeric)
#
# 2) job: type of job (categorical:"admin.","bluecollar","entrepreneur","housemaid","management","retired","self-employed","services","student","technician","unemployed","unknown")
#
# 3) marital: marital status (categorical: "divorced","married","single","unknown"; note: "divorced" means divorced or widowed)
#
# 4) education: education of individual (categorical: "basic.4y","basic.6y","basic.9y","high.school","illiterate","professional.course","university.degree","unknown")
#
# 5) default: has credit in default? (categorical: "no","yes","unknown")
#
# 6) housing: has housing loan? (categorical: "no","yes","unknown")
#
# 7) loan: has personal loan? (categorical: "no","yes","unknown")
#
# Related with the last contact of the current campaign:
#
# 8) contact: contact communication type (categorical: "cellular","telephone")
#
# 9) month: last contact month of year (categorical: "jan", "feb", "mar", …, "nov", "dec")
#
# 10) dayofweek: last contact day of the week (categorical: "mon","tue","wed","thu","fri")
#
# 11) duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y="no"). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# Other attributes:
#
# 12) campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 13) pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#
# 14) previous: number of contacts performed before this campaign and for this client (numeric)
#
# 15) poutcome: outcome of the previous marketing campaign (categorical: "failure","nonexistent","success")
#
# Social and economic context attributes
#
# 16) emp.var.rate: employment variation rate - quarterly indicator (numeric)
#
# 17) cons.price.idx: consumer price index - monthly indicator (numeric)
#
# 18) cons.conf.idx: consumer confidence index - monthly indicator (numeric)
#
# 19) concave points_se: standard error for number of concave portions of the contour
#
# 20) euribor3m: euribor 3 month rate - daily indicator (numeric)
#
# 21) nr.employed: number of employees - quarterly indicator (numeric)
#
# Output variable (desired target):
#
# 22) y: has the client subscribed a term deposit? (binary: "yes","no")

# %%
# Basics libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('bank.csv', sep=';')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#        age          job   marital            education  default housing loan  \
# 1266    39  blue-collar   married             basic.6y       no      no   no
# 12261   36      retired   married              unknown       no      no   no
# 14234   27   technician    single  professional.course       no      no   no
# 16956   47   technician  divorced          high.school       no     yes   no
# 18465   32   technician    single  professional.course       no     yes   no
# 20216   55     services   married          high.school  unknown      no   no
# 20534   41   technician   married  professional.course       no     yes   no
# 25217   39       admin.   married    university.degree       no      no   no
# 28477   24     services    single          high.school       no     yes   no
# 32516   35       admin.   married    university.degree       no     yes   no
# 36951   45       admin.   married    university.degree       no      no   no
# ...

# %%
# Removing the duplicates values by keeping first records
df.drop_duplicates(keep = 'first',inplace=True)

# %%
df.shape
# Out:
# (41176, 21)

# %%
df.reset_index(inplace = True)

# %%
df.shape
# Out:
# (41176, 22)

# %%
df.head()
# Out:
#    index  age        job  marital    education  default housing loan  \
# 0      0   56  housemaid  married     basic.4y       no      no   no
# 1      1   57   services  married  high.school  unknown      no   no
# 2      2   37   services  married  high.school       no     yes   no
# 3      3   40     admin.  married     basic.6y       no      no   no
# 4      4   56   services  married  high.school       no      no  yes
#
#      contact month  ... campaign  pdays  previous     poutcome  emp.var.rate  \
# 0  telephone   may  ...        1    999         0  nonexistent           1.1
# 1  telephone   may  ...        1    999         0  nonexistent           1.1
# 2  telephone   may  ...        1    999         0  nonexistent           1.1
# 3  telephone   may  ...        1    999         0  nonexistent           1.1
# 4  telephone   may  ...        1    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df.drop(columns=['index'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41171   73      retired  married  professional.course      no     yes   no
# 41172   46  blue-collar  married  professional.course      no      no   no
# 41173   56      retired  married    university.degree      no     yes   no
# 41174   44   technician  married  professional.course      no      no   no
# 41175   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41171  cellular   nov         fri  ...         1    999         0
# 41172  cellular   nov         fri  ...         1    999         0
# 41173  cellular   nov         fri  ...         2    999         0
# 41174  cellular   nov         fri  ...         1    999         0
# 41175  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
df.shape
# Out:
# (41176, 21)

# %%
df.describe(include = 'O')
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41176    41176              41176   41176   41176  41176     41176
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10419    24921              12164   32577   21571  33938     26135
#
#         month day_of_week     poutcome      y
# count   41176       41176        41176  41176
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13767        8618        35551  36537

# %% [markdown]
# # target variable

# %%
df.y.isnull().sum()
# Out:
# 0

# %%
df.value_counts('y')
# Out:
# y
# no     36537
# yes     4639
# dtype: int64

# %%
sns.countplot(data=df,x='y')
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
counts = df['y'].value_counts()
# Plotting the pie chart
plt.pie(counts, labels=counts.index, autopct='%1.1f%%') 
plt.title("Distribution of y")
plt.show()

# %% [markdown]
# # age

# %%
df.age.isnull().sum()
# Out:
# 0

# %%
df.value_counts('age')
# Out:
# age
# 31    1947
# 32    1845
# 33    1833
# 36    1779
# 35    1758
#       ...
# 91       2
# 98       2
# 87       1
# 94       1
# 95       1
# Length: 78, dtype: int64

# %%
sns.distplot(df.age)
plt.title('Normality of age')
# Out:
# Text(0.5, 1.0, 'Normality of age')

# %%
sns.boxplot(df.age)
# Out:
# <Axes: >

# %%
print(df.shape)
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df['age'] < (Q1 - 1.5 * IQR))|(df['age'] > (Q3 + 1.5*IQR)))]
print(df.shape)
sns.boxplot(df.age)
plt.title('Box plot of age after removing the outliers')
# Out:
# (41176, 21)
# (40708, 21)
# Text(0.5, 1.0, 'Box plot of age after removing the outliers')

# %%
sns.distplot(df.age)
plt.title('Normality of age')
# Out:
# Text(0.5, 1.0, 'Normality of age')

# %%
df.groupby('y')['age'].describe()
# Out:
#        count       mean        std   min   25%   50%   75%   max
# y
# no   36290.0  39.662028   9.446105  17.0  32.0  38.0  47.0  69.0
# yes   4418.0  39.084880  11.372360  17.0  30.0  36.0  47.0  69.0

# %% [markdown]
# #   EDA on the given data.

# %%
cat = df.select_dtypes('O')
cat.columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %%
num= df.select_dtypes( include = np.number)
num.columns
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
for col in cat.columns:
 print('Value count of :', col)
 x = cat[col].value_counts()
 y = x.sum()
 print(x)
 print('\n')
 print('Sum of value counts {0} is {1}'.format(col, y))
 print('\n')
# Out:
# Value count of : job
# admin.           10411
# blue-collar       9250
# technician        6738
# services          3967
# management        2918
# entrepreneur      1456
# self-employed     1420
# retired           1300
# housemaid         1035
# unemployed        1014
# student            875
# unknown            324
# Name: job, dtype: int64
#
#
# Sum of value counts job is 40708
#
#
# Value count of : marital
# married     24603
# single      11550
# divorced     4475
# unknown        80
# Name: marital, dtype: int64
#
#
# Sum of value counts marital is 40708
#
#
# Value count of : education
# university.degree      12102
# high.school             9478
# basic.9y                6018
# professional.course     5198
# basic.4y                3935
# basic.6y                2278
# unknown                 1682
# illiterate                17
# Name: education, dtype: int64
#
#
# Sum of value counts education is 40708
#
#
# Value count of : default
# no         32152
# unknown     8553
# ...

# %%
for col in cat.columns:
    print('Value counts of the {0} column is \n {1}'.format(col, df[col].values))
    
    # Replace 'col' with the actual column name
    sns.countplot(data=df, x=col)
    plt.title(col)
    plt.xticks(rotation =90)
    plt.show()
# Out:
# Value counts of the job column is
#  ['housemaid' 'services' 'services' ... 'blue-collar' 'retired'
#  'technician']
# Value counts of the marital column is
#  ['married' 'married' 'married' ... 'married' 'married' 'married']
# Value counts of the education column is
#  ['basic.4y' 'high.school' 'high.school' ... 'professional.course'
#  'university.degree' 'professional.course']
# Value counts of the default column is
#  ['no' 'unknown' 'no' ... 'no' 'no' 'no']
# Value counts of the housing column is
#  ['no' 'no' 'yes' ... 'no' 'yes' 'no']
# Value counts of the loan column is
#  ['no' 'no' 'no' ... 'no' 'no' 'no']
# Value counts of the contact column is
#  ['telephone' 'telephone' 'telephone' ... 'cellular' 'cellular' 'cellular']
# Value counts of the month column is
#  ['may' 'may' 'may' ... 'nov' 'nov' 'nov']
# Value counts of the day_of_week column is
#  ['mon' 'mon' 'mon' ... 'fri' 'fri' 'fri']
# Value counts of the poutcome column is
# ...

# %%
#Now we Compare Target variable with CategoricalColumns
for col in cat:
    plt.figure(figsize=(15, 5))
    sns.countplot(data=df, x=col, hue='y')
    plt.title('Comparing with the Target variable')
    plt.show()

# %% [markdown]
# pre-processing tasks

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cmap = 'flare')
# Out:
# <Axes: >

# %%
from sklearn import preprocessing
label_e = preprocessing.LabelEncoder()

# %%
for col in cat:
    df[col] = label_e.fit_transform(df[col])

# %%
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3        1        0     0        1      6
# 2   37    7        1          3        0        2     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     2        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         1    999         0         1           1.1
# 1            1  ...         1    999         0         1           1.1
# 2            1  ...         1    999         0         1           1.1
# 3            1  ...         1    999         0         1           1.1
# 4            1  ...         1    999         0         1           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
plt.figure(figsize = (14, 12))
sns.heatmap(df.corr(), annot = True, linewidth = .5)
plt.show()

# %% [markdown]
# # Selecting important features based on Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split

# %%
X = df.drop('y', axis=1)
y=df['y']

# %%
X_train, Xtest, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
X_train.shape
# Out:
# (28495, 20)

# %%
y_test.shape
# Out:
# (12213,)

# %%
model = SelectFromModel(RandomForestClassifier(n_estimators= 100))
model.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
model.get_support()
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#         True,  True])

# %%
S_Feat = X_train.columns[(model.get_support())]
len(S_Feat)
# Out:
# 4

# %%
print(S_Feat)
# Out:
# Index(['age', 'duration', 'euribor3m', 'nr.employed'], dtype='object')

# %%
RFC = RandomForestClassifier(n_estimators = 150)
random_forest = RFC.fit(X_train, y_train)

# %%
feature_importances = pd.DataFrame({'Feature': X_train.columns, 'Importance': random_forest.feature_importances_})
feature_importances = feature_importances.sort_values('Importance', ascending=False)
# Display the feature importances
print(feature_importances)
# Out:
#            Feature  Importance
# 10        duration    0.321366
# 18       euribor3m    0.111456
# 0              age    0.090949
# 19     nr.employed    0.063372
# 1              job    0.048305
# 3        education    0.044062
# 11        campaign    0.043168
# 9      day_of_week    0.040163
# 12           pdays    0.031764
# 14        poutcome    0.026818
# 17   cons.conf.idx    0.025730
# 2          marital    0.024131
# 16  cons.price.idx    0.022290
# 15    emp.var.rate    0.021537
# 5          housing    0.020212
# 8            month    0.017807
# 6             loan    0.015020
# 13        previous    0.013058
# 7          contact    0.010342
# 4          default    0.008449

# %% [markdown]
# # Handling unbalanced data using SMOTE

# %%
from sklearn.utils import resample

# %%
df.y.value_counts()
# Out:
# 0    36290
# 1     4418
# Name: y, dtype: int64

# %%
not_y = df[df.y == 0]
len(not_y)
# Out:
# 36290

# %%
yes_y = df[df.y == 1]
len(yes_y)
# Out:
# 4418

# %%
y_df = resample(yes_y, replace = True, n_samples = len(not_y), random_state =0)

# %%
y_df
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 37111   61    5        1          5        0        0     0        0      1
# 36748   49    7        1          3        0        0     0        0      4
# 29587   57    2        2          6        0        2     0        0      0
# 38704   38    0        1          6        0        2     0        0      7
# 21991   29    9        2          3        1        0     0        0      1
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 33308   37    0        0          6        0        2     0        0      6
# 26437   46    4        1          7        0        2     0        0      7
# 27170   57    4        0          5        0        2     0        0      7
# 38094   46    6        0          3        0        0     0        0      9
# 31232   31    7        1          3        0        2     0        0      6
#
# ...

# %%
balanced_df = pd.concat([not_y, y_df])

# %%
balanced_df
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 1       57    7        1          3        1        0     0        1      6
# 2       37    7        1          3        0        2     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 33308   37    0        0          6        0        2     0        0      6
# 26437   46    4        1          7        0        2     0        0      7
# 27170   57    4        0          5        0        2     0        0      7
# 38094   46    6        0          3        0        0     0        0      9
# 31232   31    7        1          3        0        2     0        0      6
#
# ...

# %%
y_train.value_counts()
# Out:
# 0    25363
# 1     3132
# Name: y, dtype: int64

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
SM = SMOTE(random_state = 6)

# %%
SM_x, SM_y = SM.fit_resample(X_train, y_train)

# %%
SM_y.value_counts()
# Out:
# 0    25363
# 1    25363
# Name: y, dtype: int64

# %% [markdown]
# # Standardize the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
Num_Features = balanced_df[['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']]

# %%
Num_Features
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 33308   37       918         1    999         0          -1.8          92.893
# 26437   46      1503         2    999         0          -0.1          93.200
# 27170   57       849         1    999         0          -0.1          93.200
# 38094   46       267         2    999         1          -3.4          92.379
# 31232   31       611         1    999         1          -1.8          92.893
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
MM_Scaler = MinMaxScaler()

# %%
Columns = Num_Features.columns

# %%
Num_Features = MM_Scaler.fit_transform(Num_Features)

# %%
Num_Features
# Out:
# array([[0.75      , 0.05307035, 0.        , ..., 0.60251046, 0.95737928,
#         0.85973535],
#        [0.76923077, 0.03029687, 0.        , ..., 0.60251046, 0.95737928,
#         0.85973535],
#        [0.38461538, 0.04595364, 0.        , ..., 0.60251046, 0.95737928,
#         0.85973535],
#        ...,
#        [0.76923077, 0.17263115, 0.        , ..., 0.36820084, 0.76785309,
#         0.8778828 ],
#        [0.55769231, 0.05429036, 0.01818182, ..., 0.87866109, 0.02901836,
#         0.20378072],
#        [0.26923077, 0.12423749, 0.        , ..., 0.19246862, 0.15869417,
#         0.51228733]])

# %%
df_Num_Features = pd.DataFrame(Num_Features, columns = Columns)

# %%
df_Num_Features
# Out:
#             age  duration  campaign  pdays  previous  emp.var.rate  \
# 0      0.750000  0.053070  0.000000    1.0  0.000000      0.937500
# 1      0.769231  0.030297  0.000000    1.0  0.000000      0.937500
# 2      0.384615  0.045954  0.000000    1.0  0.000000      0.937500
# 3      0.442308  0.030704  0.000000    1.0  0.000000      0.937500
# 4      0.750000  0.062424  0.000000    1.0  0.000000      0.937500
# ...         ...       ...       ...    ...       ...           ...
# 72575  0.384615  0.186661  0.000000    1.0  0.000000      0.333333
# 72576  0.557692  0.305612  0.018182    1.0  0.000000      0.687500
# 72577  0.769231  0.172631  0.000000    1.0  0.000000      0.687500
# 72578  0.557692  0.054290  0.018182    1.0  0.142857      0.000000
# 72579  0.269231  0.124237  0.000000    1.0  0.142857      0.333333
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0            0.698753       0.602510   0.957379     0.859735
# ...

# %%
Sc_df = balanced_df.copy()

# %%
Sc_df = balanced_df.drop(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],axis=1)

# %%
Sc_df
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        3        1          0        0        0     0        1      6
# 1        7        1          3        1        0     0        1      6
# 2        7        1          3        0        2     0        1      6
# 3        0        1          1        0        0     0        1      6
# 4        7        1          3        0        0     2        1      6
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 33308    0        0          6        0        2     0        0      6
# 26437    4        1          7        0        2     0        0      7
# 27170    4        0          5        0        2     0        0      7
# 38094    6        0          3        0        0     0        0      9
# 31232    7        1          3        0        2     0        0      6
#
#        day_of_week  poutcome  y
# 0                1         1  0
# 1                1         1  0
# ...

# %%
Sc_df.reset_index(inplace = True, drop = True)

# %%
Sc_df
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        3        1          0        0        0     0        1      6
# 1        7        1          3        1        0     0        1      6
# 2        7        1          3        0        2     0        1      6
# 3        0        1          1        0        0     0        1      6
# 4        7        1          3        0        0     2        1      6
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 72575    0        0          6        0        2     0        0      6
# 72576    4        1          7        0        2     0        0      7
# 72577    4        0          5        0        2     0        0      7
# 72578    6        0          3        0        0     0        0      9
# 72579    7        1          3        0        2     0        0      6
#
#        day_of_week  poutcome  y
# 0                1         1  0
# 1                1         1  0
# ...

# %%
data1 = pd.concat([df_Num_Features, Sc_df], axis = 1)

# %%
data1
# Out:
#             age  duration  campaign  pdays  previous  emp.var.rate  \
# 0      0.750000  0.053070  0.000000    1.0  0.000000      0.937500
# 1      0.769231  0.030297  0.000000    1.0  0.000000      0.937500
# 2      0.384615  0.045954  0.000000    1.0  0.000000      0.937500
# 3      0.442308  0.030704  0.000000    1.0  0.000000      0.937500
# 4      0.750000  0.062424  0.000000    1.0  0.000000      0.937500
# ...         ...       ...       ...    ...       ...           ...
# 72575  0.384615  0.186661  0.000000    1.0  0.000000      0.333333
# 72576  0.557692  0.305612  0.018182    1.0  0.000000      0.687500
# 72577  0.769231  0.172631  0.000000    1.0  0.000000      0.687500
# 72578  0.557692  0.054290  0.018182    1.0  0.142857      0.000000
# 72579  0.269231  0.124237  0.000000    1.0  0.142857      0.333333
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ...  marital  \
# 0            0.698753       0.602510   0.957379     0.859735  ...        1
# ...

# %%
data1[data1.duplicated()]
# Out:
#             age  duration  campaign     pdays  previous  emp.var.rate  \
# 36328  0.365385  0.113461  0.000000  1.000000  0.000000      0.333333
# 36447  0.519231  0.237698  0.000000  1.000000  0.000000      1.000000
# 36471  0.711538  0.101464  0.000000  1.000000  0.000000      0.333333
# 36496  0.788462  0.647214  0.018182  1.000000  0.000000      1.000000
# 36531  0.750000  0.077877  0.000000  0.003003  0.142857      0.354167
# ...         ...       ...       ...       ...       ...           ...
# 72575  0.384615  0.186661  0.000000  1.000000  0.000000      0.333333
# 72576  0.557692  0.305612  0.018182  1.000000  0.000000      0.687500
# 72577  0.769231  0.172631  0.000000  1.000000  0.000000      0.687500
# 72578  0.557692  0.054290  0.018182  1.000000  0.142857      0.000000
# 72579  0.269231  0.124237  0.000000  1.000000  0.142857      0.333333
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ...  marital  \
# ...

# %%
data1 = data1.drop_duplicates()

# %%
data1.shape
# Out:
# (40707, 21)

# %%
data1.reset_index(drop=True,inplace=True)

# %%
data1.tail()
# Out:
#             age  duration  campaign  pdays  previous  emp.var.rate  \
# 40702  0.730769  0.106954  0.054545    1.0  0.142857      0.333333
# 40703  0.326923  0.028874  0.000000    1.0  0.000000      0.333333
# 40704  0.519231  0.063034  0.000000    1.0  0.142857      0.479167
# 40705  0.519231  0.159821  0.000000    1.0  0.000000      0.937500
# 40706  0.961538  0.094754  0.000000    1.0  0.000000      0.104167
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ...  marital  \
# 40702        0.269680       0.192469   0.146679     0.512287  ...        0
# 40703        0.340608       0.154812   0.178871     0.512287  ...        2
# 40704        0.935308       0.054393   0.082974     0.000000  ...        1
# 40705        0.698753       0.602510   0.957153     0.859735  ...        1
# 40706        0.296960       0.418410   0.142371     0.425709  ...        1
#
#        education  default  housing  loan  contact  month  day_of_week  \
# ...

# %%
null_features = data1.isnull().sum()
null_features[null_features>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Building the following Supervised Learning models:
# a. Logistic Regression
#
# b. Decision Trees
#
# c. Random Forest

# %% [markdown]
# ## a.LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve,roc_auc_score

# %%
X = data1.drop(['y'], axis = 1)
y = data1['y']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (32565, 20)
# (32565,)

# %%
LR=LogisticRegression()
LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = LR.predict(X_train)
y_test_pred = LR.predict(X_test)

# %%
print(classification_report(y_train,y_train_pred))
print(confusion_matrix(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     29039
#            1       0.68      0.39      0.49      3526
#
#     accuracy                           0.91     32565
#    macro avg       0.81      0.68      0.72     32565
# weighted avg       0.90      0.91      0.90     32565
#
# [[28403   636]
#  [ 2163  1363]]

# %%
print(classification_report(y_test,y_test_pred))
print(confusion_matrix(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      7251
#            1       0.64      0.36      0.46       891
#
#     accuracy                           0.91      8142
#    macro avg       0.78      0.67      0.71      8142
# weighted avg       0.89      0.91      0.90      8142
#
# [[7072  179]
#  [ 569  322]]

# %% [markdown]
# # b. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion='gini')
classifier.fit(X_train, y_train)
classifier.score(X_test, y_test)
# Out:
# 0.8917956276099238

# %%
classifier_entropy = DecisionTreeClassifier(criterion='entropy')
classifier_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
classifier_entropy.score(X_test, y_test)
# Out:
# 0.8911815278801277

# %% [markdown]
# # c. Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = rf.predict(X_test)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96      7251
#            1       0.67      0.53      0.59       891
#
#     accuracy                           0.92      8142
#    macro avg       0.81      0.75      0.77      8142
# weighted avg       0.91      0.92      0.92      8142

# %%
# Feature Selection Technique
from sklearn.ensemble import ExtraTreesClassifier

# %%
ETC=ExtraTreesClassifier()
ETC.fit(X,y)
print(ETC.feature_importances_)
F_imp=pd.Series(ETC.feature_importances_,index=X.columns)
print(F_imp)
F_imp.sort_values(ascending=False).plot(kind='bar')
X_imp=X[F_imp.nlargest(13).index]
X_train,X_test,y_train,y_test= train_test_split(X_imp,y,test_size=0.2,random_state=10)
# Out:
# [0.08705367 0.26949598 0.06024593 0.04400704 0.01301152 0.02375928
#  0.01896003 0.02393212 0.09645903 0.05458607 0.05860749 0.03497538
#  0.05448506 0.01084653 0.02676702 0.01969487 0.01329027 0.01530398
#  0.0494059  0.02511281]
# age               0.087054
# duration          0.269496
# campaign          0.060246
# pdays             0.044007
# previous          0.013012
# emp.var.rate      0.023759
# cons.price.idx    0.018960
# cons.conf.idx     0.023932
# euribor3m         0.096459
# nr.employed       0.054586
# job               0.058607
# marital           0.034975
# education         0.054485
# default           0.010847
# housing           0.026767
# loan              0.019695
# contact           0.013290
# month             0.015304
# day_of_week       0.049406
# poutcome          0.025113
# dtype: float64

# %%
RFC=RandomForestClassifier()
RFC.fit(X_train,y_train)
train_pred=RFC.predict(X_train)
train_pred
test_pred=RFC.predict(X_test)
test_pred
train_mean_sq=mean_squared_error(train_pred,y_train)
print('train_mean_sq=',train_mean_sq)
test_mean_sq=mean_squared_error(test_pred,y_test)
print('test_mean_sq=',test_mean_sq)
train_accuracy=accuracy_score(train_pred,y_train)*100
print('train_accuracy=',train_accuracy)
test_accuracy=accuracy_score(test_pred,y_test)*100
print('test_accuracy=',test_accuracy)
# Out:
# train_mean_sq= 3.070781513895286e-05
# test_mean_sq= 0.08757062146892655
# train_accuracy= 99.9969292184861
# test_accuracy= 91.24293785310734

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
criterion=["gini", "entropy", "log_loss"]
# Number of features to consider at every split
max_features = ["sqrt", "log2"]
# The depth of the tree max_depth
max_depth = [i for i in range(5,20,6)]
# Min samples required to split the node
min_sample_split = [2,5,10,15,50]
# Min no of samples required to each leaf to split  ---- Pruning
min_samples_leaf = [1,2,5,10]
decetion_grid = {'criterion':criterion,
              'max_features':max_features,
              'max_depth':max_depth,
              'min_samples_split':min_sample_split,
              'min_samples_leaf':min_samples_leaf}
RSC=RandomizedSearchCV(estimator=RFC, param_distributions=decetion_grid,cv=4,random_state=10)

# %%
RSC.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=4, estimator=RandomForestClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': [5, 11, 17],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               50]},
#                    random_state=10)

# %%
RSC.best_params_
# Out:
# {'min_samples_split': 50,
#  'min_samples_leaf': 5,
#  'max_features': 'log2',
#  'max_depth': 17,
#  'criterion': 'gini'}

# %%
RFC=RandomForestClassifier(criterion='gini',max_depth= 17,max_features='sqrt',min_samples_leaf=10,min_samples_split=10)
RFC.fit(X_train,y_train)
train_pred=RFC.predict(X_train)
train_pred
test_pred=RFC.predict(X_test)
test_pred
train_mean_sq=mean_squared_error(train_pred,y_train)
print('train_mean_sq=',train_mean_sq)
test_mean_sq=mean_squared_error(test_pred,y_test)
print('test_mean_sq=',test_mean_sq)
train_accuracy=accuracy_score(train_pred,y_train)*100
print('train_accuracy=',train_accuracy)
test_accuracy=accuracy_score(test_pred,y_test)*100
print('test_accuracy=',test_accuracy)
# Out:
# train_mean_sq= 0.06049439582373714
# test_mean_sq= 0.08609678211741587
# train_accuracy= 93.95056041762628
# test_accuracy= 91.3903217882584

# %% [markdown]
# # Random Forest Hyperparameter is best for my data.
